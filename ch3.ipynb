# %% [markdown]
# <a href="https://colab.research.google.com/github/fkurugollu/DS_Python/blob/main/ch3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3+4
# Out:
# 7

# %%
3 * * 4
# Out:
#   File "/tmp/ipython-input-3671972048.py", line 1
#     3 * * 4
#         ^
# SyntaxError: invalid syntax

# %%
3**4
# Out:
# 81

# %% [markdown]
# ### part1
# - First
#   - Second
#      - Markdown jupyter
